# %%
# Python program to translate
# speech to text and text to speech


import speech_recognition as sr
import pyttsx3 

# Initialize the recognizer 
r = sr.Recognizer() 

# Function to convert text to
# speech
def SpeakText(command):
	
	# Initialize the engine
	engine = pyttsx3.init()
	engine.say(command) 
	engine.runAndWait()
	
	
# Loop infinitely for user to
# speak

while(1): 
	
	# Exception handling to handle
	# exceptions at the runtime
	try:
		
		# use the microphone as source for input.
		with sr.Microphone() as source2:
			
			# wait for a second to let the recognizer
			# adjust the energy threshold based on
			# the surrounding noise level 
			r.adjust_for_ambient_noise(source2, duration=0.2)
			
			#listens for the user's input 
			audio2 = r.listen(source2)
			
			# Using google to recognize audio
			MyText = r.recognize_google(audio2)
			MyText = MyText.lower()

			print("Did you say ",MyText)
			SpeakText(MyText)
			
	except sr.RequestError as e:
		print("Could not request results; {0}".format(e))
		
	except sr.UnknownValueError:
		print("unknown error occurred")
# Out:
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# Did you say  ek aisa error hai unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# Did you say  lekin kab le raha hai kaise kar raha hai yah mere ko kaise uthaya jahan per usne bola ek aisa error hai jabki meri speech leni chahie
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# unknown error occurred
# Did you say  mere se kam kya kar rahe ho main to kuchh bhi kar diya
# unknown error occurred
# unknown error occurred
# Did you say  i am priyanshu tiwari i am 21 years old i am in bangalore right now i am frustrated i am going to drive a car wish me luck
# unknown error occurred
# Did you say  video record ho gaya hairan
# Did you say  varna maine yah vs code mein chalaya ek bar mein ran karke jo code tha vahi maine copy pest mara yahan per proper chal raha hai ismein bus ek chij hamen change karni padegi yahan per yah while van likh raha hai iska matlab hai bhai hamesha hi chalata rahega infinite loop hai jiski vajah se jab tak main nahin bol raha hun tab tak ke dikha raha hai unknown error occurred aur vah dikhate hi rahega jaise maine yahan kab le raha hai kaise kar raha hai aaram ke sath english english
# unknown error occurred
# unknown error occurred
# Did you say  nahin abhi aaega thoda time nahin rahega
# Did you say  bahan chod
# Did you say  pronounce nahin kar paye
# unknown error occurred
# Did you say  unknown error account
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 39
#      36 r.adjust_for_ambient_noise(source2, duration=0.2)
#      38 #listens for the user's input
# ---> 39 audio2 = r.listen(source2)
#      41 # Using google to recognize audio
#      42 MyText = r.recognize_google(audio2)
#
# File c:\Users\Priyanshu Tiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\speech_recognition\__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     520 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#     525 frames.append(buffer)
#
# File c:\Users\Priyanshu Tiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File c:\Users\Priyanshu Tiwari\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:

# %%
for i in range(-5, -8):
    print(i)
